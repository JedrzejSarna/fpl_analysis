# %%
from _01_datasets import *
from _02_plots import *

# %%
datasets = DATASETS()
plots = PLOTS()

# %%
datasets.build_players_dataset()
datasets.build_teams_dataset()
datasets.build_gameweeks_dataset()
datasets.build_positions_dataset()

# %%
datasets.transform_players_dataset()

# %%
plots.pointplot_best_player_per_team_points(datasets.df_best_player_per_team_pts())

# %%
plots.scatterplot_top50_pts_creativity_vs_threat(datasets.df_top50_pts_creativity_vs_threat(), save=True)

# %%
plots.barplot_top5_overperformers(datasets.df_GA_vs_xGA_performance())

# %%
plots.barplot_fplpoints_per_club(datasets.df_fplpoints_per_club())

# %%
plots.barplot_top5_underperformers(datasets.df_GA_vs_xGA_performance())

# %%
datasets.df_top5_player_pts()
# Out:
#     Salah  Son  Watkins  Haaland  Bowen
# 1       5    2        5     13.0      9
# 2      10    5       10     15.0     11
# 3      15    8       15     19.0     23
# 4      23   28       17     39.0     30
# 5      33   30       22     45.0     32
# 6      43   44       31     51.0     39
# 7      44   51       54     53.0     48
# 8      59   54       59     55.0     50
# 9      75   68       70     63.0     58
# 10     83   78       72     79.0     60
# 11     85   80       74     80.0     67
# 12    101   82       80     96.0     75
# 13    106   84       85    103.0     75
# 14    111   94       96    110.0     77
# 15    114   96       97    112.0     84
# 16    127  113       99    112.0     86
# 17    130  115      108    112.0     94
# 18    137  122      110    112.0    102
# 19    140  127      112    112.0    108
# 20    156  136      120    112.0    111

# %%
plots.pointplot_top5_player_points(datasets.df_top5_player_pts())

# %%
plots.pointplot_top5_defender_points(datasets.df_top5_defender_pts())

# %%
plots.pointplot_top5_midfielder_points(datasets.df_top5_midfielder_pts())

# %%
datasets.get_player_id("Cash")
# Out:
# 36

# %%
datasets.df_player_past_seasons('Haaland')
# Out:
#   season_name  start_cost  end_cost  total_points  minutes  goals_scored  \
# 0     2022/23         115       124           272     2767            36
#
#    assists  clean_sheets  goals_conceded  own_goals  penalties_saved  \
# 0        9            13              26          0                0
#
#    penalties_missed  yellow_cards  red_cards  saves  bonus   bps influence  \
# 0                 0             5          0      0     40  1040    1390.0
#
#   creativity  threat ict_index  starts expected_goals expected_assists  \
# 0      371.0  1825.0     358.1      33          28.54             3.11
#
#   expected_goal_involvements expected_goals_conceded
# 0                      31.65                   25.24

# %%
datasets.get_player_json('Bukayo Saka')
# Out:
# {'fixtures': [{'id': 167,
#    'code': 2367704,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 8,
#    'team_a_score': None,
#    'event': 17,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-16T15:00:00Z',
#    'event_name': 'Gameweek 17',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 187,
#    'code': 2367724,
#    'team_h': 9,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 19,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-27T20:15:00Z',
#    'event_name': 'Gameweek 19',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 196,
#    'code': 2367733,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 17,
#    'team_a_score': None,
#    'event': 20,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-30T15:00:00Z',
#    'event_name': 'Gameweek 20',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 209,
#    'code': 2367746,
#    'team_h': 15,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 21,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-01-13T17:30:00Z',
#    'event_name': 'Gameweek 21',
#    'is_home': False,
#    'difficulty': 4},
#   {'id': 220,
#    'code': 2367757,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 6,
#    'team_a_score': None,
#    'event': 22,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-01-31T19:30:00Z',
#    'event_name': 'Gameweek 22',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 223,
#    'code': 2367760,
#    'team_h': 4,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 23,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-03T15:00:00Z',
#    'event_name': 'Gameweek 23',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 236,
#    'code': 2367773,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 9,
#    'team_a_score': None,
#    'event': 24,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-10T15:00:00Z',
#    'event_name': 'Gameweek 24',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 246,
#    'code': 2367783,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 7,
#    'team_a_score': None,
#    'event': 25,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-17T15:00:00Z',
#    'event_name': 'Gameweek 25',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 253,
#    'code': 2367788,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 26,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-24T15:00:00Z',
#    'event_name': 'Gameweek 26',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 266,
#    'code': 2367803,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 14,
#    'team_a_score': None,
#    'event': 27,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-02T15:00:00Z',
#    'event_name': 'Gameweek 27',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 277,
#    'code': 2367814,
#    'team_h': 11,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 28,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-09T15:00:00Z',
#    'event_name': 'Gameweek 28',
#    'is_home': False,
#    'difficulty': 4},
#   {'id': 282,
#    'code': 2367819,
#    'team_h': 5,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 29,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-16T15:00:00Z',
#    'event_name': 'Gameweek 29',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 296,
#    'code': 2367833,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 1,
#    'team_a_score': None,
#    'event': 30,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-30T15:00:00Z',
#    'event_name': 'Gameweek 30',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 309,
#    'code': 2367846,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 2,
#    'team_a_score': None,
#    'event': 31,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-03T19:00:00Z',
#    'event_name': 'Gameweek 31',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 313,
#    'code': 2367850,
#    'team_h': 8,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 32,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-06T14:00:00Z',
#    'event_name': 'Gameweek 32',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 327,
#    'code': 2367864,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 12,
#    'team_a_score': None,
#    'event': 33,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-13T14:00:00Z',
#    'event_name': 'Gameweek 33',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 339,
#    'code': 2367876,
#    'team_h': 18,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 34,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-20T14:00:00Z',
#    'event_name': 'Gameweek 34',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 347,
#    'code': 2367884,
#    'team_h': 16,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 35,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-27T14:00:00Z',
#    'event_name': 'Gameweek 35',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 359,
#    'code': 2367896,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 20,
#    'team_a_score': None,
#    'event': 36,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-04T14:00:00Z',
#    'event_name': 'Gameweek 36',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 364,
#    'code': 2367901,
#    'team_h': 10,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 37,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-11T14:00:00Z',
#    'event_name': 'Gameweek 37',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 379,
#    'code': 2367916,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 19,
#    'team_a_score': None,
#    'event': 38,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-19T15:00:00Z',
#    'event_name': 'Gameweek 38',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 176,
#    'code': 2367713,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 4,
#    'team_a_score': None,
#    'event': None,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': None,
#    'is_home': True,
#    'difficulty': 3}],
#  'history': [{'element': 342,
#    'fixture': 1,
#    'opponent_team': 6,
#    'total_points': 7,
#    'was_home': False,
#    'kickoff_time': '2023-08-11T19:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 3,
#    'round': 1,
#    'minutes': 78,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 1,
#    'bps': 32,
#    'influence': '14.2',
#    'creativity': '1.9',
#    'threat': '10.0',
#    'ict_index': '2.6',
#    'starts': 1,
#    'expected_goals': '0.31',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.32',
#    'expected_goals_conceded': '0.23',
#    'value': 50,
#    'transfers_balance': 0,
#    'selected': 293028,
#    'transfers_in': 0,
#    'transfers_out': 0},
#   {'element': 342,
#    'fixture': 16,
#    'opponent_team': 15,
#    'total_points': 0,
#    'was_home': True,
#    'kickoff_time': '2023-08-19T19:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 0,
#    'round': 2,
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 50,
#    'transfers_balance': 201248,
#    'selected': 664994,
#    'transfers_in': 229935,
#    'transfers_out': 28687},
#   {'element': 342,
#    'fixture': 30,
#    'opponent_team': 17,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2023-08-27T13:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 2,
#    'round': 3,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 15,
#    'influence': '16.8',
#    'creativity': '1.7',
#    'threat': '9.0',
#    'ict_index': '2.8',
#    'starts': 1,
#    'expected_goals': '0.11',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.12',
#    'expected_goals_conceded': '0.73',
#    'value': 51,
#    'transfers_balance': -51660,
#    'selected': 623749,
#    'transfers_in': 61576,
#    'transfers_out': 113236},
#   {'element': 342,
#    'fixture': 39,
#    'opponent_team': 10,
#    'total_points': 8,
#    'was_home': True,
#    'kickoff_time': '2023-09-02T14:00:00Z',
#    'team_h_score': 5,
#    'team_a_score': 1,
#    'round': 4,
#    'minutes': 90,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 27,
#    'influence': '45.2',
#    'creativity': '2.9',
#    'threat': '19.0',
#    'ict_index': '6.7',
#    'starts': 1,
#    'expected_goals': '0.03',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.04',
#    'expected_goals_conceded': '1.45',
#    'value': 51,
#    'transfers_balance': 1235,
#    'selected': 645859,
#    'transfers_in': 49995,
#    'transfers_out': 48760},
#   {'element': 342,
#    'fixture': 49,
#    'opponent_team': 19,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2023-09-16T14:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 3,
#    'round': 5,
#    'minutes': 1,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 3,
#    'influence': '0.2',
#    'creativity': '0.1',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 51,
#    'transfers_balance': 102441,
#    'selected': 789816,
#    'transfers_in': 138862,
#    'transfers_out': 36421},
#   {'element': 342,
#    'fixture': 59,
#    'opponent_team': 16,
#    'total_points': 1,
#    'was_home': True,
#    'kickoff_time': '2023-09-23T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 6,
#    'minutes': 33,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 7,
#    'influence': '2.2',
#    'creativity': '10.5',
#    'threat': '2.0',
#    'ict_index': '1.5',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.20',
#    'expected_goal_involvements': '0.20',
#    'expected_goals_conceded': '0.77',
#    'value': 51,
#    'transfers_balance': -29934,
#    'selected': 761425,
#    'transfers_in': 38449,
#    'transfers_out': 68383},
#   {'element': 342,
#    'fixture': 70,
#    'opponent_team': 20,
#    'total_points': 1,
#    'was_home': False,
#    'kickoff_time': '2023-09-30T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 1,
#    'round': 7,
#    'minutes': 79,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 11,
#    'influence': '8.6',
#    'creativity': '9.8',
#    'threat': '45.0',
#    'ict_index': '6.3',
#    'starts': 1,
#    'expected_goals': '0.11',
#    'expected_assists': '0.02',
#    'expected_goal_involvements': '0.13',
#    'expected_goals_conceded': '0.44',
#    'value': 51,
#    'transfers_balance': -83688,
#    'selected': 679270,
#    'transfers_in': 14951,
#    'transfers_out': 98639},
#   {'element': 342,
#    'fixture': 71,
#    'opponent_team': 1,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2023-10-08T15:30:00Z',
#    'team_h_score': 1,
#    'team_a_score': 0,
#    'round': 8,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 13,
#    'influence': '12.2',
#    'creativity': '1.2',
#    'threat': '4.0',
#    'ict_index': '1.7',
#    'starts': 1,
#    'expected_goals': '0.30',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.31',
#    'expected_goals_conceded': '0.41',
#    'value': 51,
#    'transfers_balance': -48237,
#    'selected': 636028,
#    'transfers_in': 11109,
#    'transfers_out': 59346},
#   {'element': 342,
#    'fixture': 86,
#    'opponent_team': 5,
#    'total_points': 1,
#    'was_home': True,
#    'kickoff_time': '2023-10-21T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 1,
#    'round': 9,
#    'minutes': 1,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 3,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 51,
#    'transfers_balance': -16099,
#    'selected': 628213,
#    'transfers_in': 14983,
#    'transfers_out': 31082},
#   {'element': 342,
#    'fixture': 98,
#    'opponent_team': 14,
#    'total_points': 0,
#    'was_home': False,
#    'kickoff_time': '2023-10-29T15:30:00Z',
#    'team_h_score': 0,
#    'team_a_score': 3,
#    'round': 10,
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 51,
#    'transfers_balance': -41975,
#    'selected': 587366,
#    'transfers_in': 7405,
#    'transfers_out': 49380},
#   {'element': 342,
#    'fixture': 106,
#    'opponent_team': 3,
#    'total_points': 9,
#    'was_home': True,
#    'kickoff_time': '2023-11-04T15:00:00Z',
#    'team_h_score': 6,
#    'team_a_score': 1,
#    'round': 11,
#    'minutes': 90,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 1,
#    'bps': 30,
#    'influence': '48.6',
#    'creativity': '24.3',
#    'threat': '37.0',
#    'ict_index': '11.0',
#    'starts': 1,
#    'expected_goals': '0.28',
#    'expected_assists': '0.03',
#    'expected_goal_involvements': '0.31',
#    'expected_goals_conceded': '0.77',
#    'value': 50,
#    'transfers_balance': -39422,
#    'selected': 550415,
#    'transfers_in': 7799,
#    'transfers_out': 47221},
#   {'element': 342,
#    'fixture': 115,
#    'opponent_team': 7,
#    'total_points': 0,
#    'was_home': False,
#    'kickoff_time': '2023-11-12T16:30:00Z',
#    'team_h_score': 4,
#    'team_a_score': 4,
#    'round': 12,
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 50,
#    'transfers_balance': 16986,
#    'selected': 572815,
#    'transfers_in': 34175,
#    'transfers_out': 17189},
#   {'element': 342,
#    'fixture': 126,
#    'opponent_team': 11,
#    'total_points': 7,
#    'was_home': True,
#    'kickoff_time': '2023-11-25T12:30:00Z',
#    'team_h_score': 1,
#    'team_a_score': 1,
#    'round': 13,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 1,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 2,
#    'bps': 27,
#    'influence': '36.2',
#    'creativity': '13.1',
#    'threat': '0.0',
#    'ict_index': '4.9',
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.03',
#    'expected_goal_involvements': '0.03',
#    'expected_goals_conceded': '0.56',
#    'value': 50,
#    'transfers_balance': -61591,
#    'selected': 506940,
#    'transfers_in': 4355,
#    'transfers_out': 65946},
#   {'element': 342,
#    'fixture': 137,
#    'opponent_team': 18,
#    'total_points': 1,
#    'was_home': True,
#    'kickoff_time': '2023-12-03T16:30:00Z',
#    'team_h_score': 3,
#    'team_a_score': 3,
#    'round': 14,
#    'minutes': 3,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 3,
#    'influence': '0.2',
#    'creativity': '0.3',
#    'threat': '0.0',
#    'ict_index': '0.1',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.11',
#    'value': 50,
#    'transfers_balance': 32494,
#    'selected': 549201,
#    'transfers_in': 39922,
#    'transfers_out': 7428},
#   {'element': 342,
#    'fixture': 141,
#    'opponent_team': 2,
#    'total_points': 0,
#    'was_home': False,
#    'kickoff_time': '2023-12-06T20:15:00Z',
#    'team_h_score': 1,
#    'team_a_score': 0,
#    'round': 15,
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'value': 50,
#    'transfers_balance': -3978,
#    'selected': 544790,
#    'transfers_in': 12161,
#    'transfers_out': 16139},
#   {'element': 342,
#    'fixture': 156,
#    'opponent_team': 12,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2023-12-10T14:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 2,
#    'round': 16,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 22,
#    'influence': '21.8',
#    'creativity': '11.7',
#    'threat': '8.0',
#    'ict_index': '4.2',
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.15',
#    'expected_goal_involvements': '0.15',
#    'expected_goals_conceded': '0.33',
#    'value': 50,
#    'transfers_balance': -4695,
#    'selected': 541815,
#    'transfers_in': 15241,
#    'transfers_out': 19936}],
#  'history_past': [{'season_name': '2012/13',
#    'element_code': 126184,
#    'start_cost': 40,
#    'end_cost': 40,
#    'total_points': 4,
#    'minutes': 92,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2013/14',
#    'element_code': 126184,
#    'start_cost': 45,
#    'end_cost': 42,
#    'total_points': 1,
#    'minutes': 12,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 1,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2014/15',
#    'element_code': 126184,
#    'start_cost': 45,
#    'end_cost': 43,
#    'total_points': 1,
#    'minutes': 18,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 2,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2015/16',
#    'element_code': 126184,
#    'start_cost': 45,
#    'end_cost': 44,
#    'total_points': 73,
#    'minutes': 1874,
#    'goals_scored': 1,
#    'assists': 1,
#    'clean_sheets': 7,
#    'goals_conceded': 25,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 4,
#    'red_cards': 1,
#    'saves': 0,
#    'bonus': 7,
#    'bps': 378,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2016/17',
#    'element_code': 126184,
#    'start_cost': 45,
#    'end_cost': 39,
#    'total_points': 55,
#    'minutes': 834,
#    'goals_scored': 3,
#    'assists': 1,
#    'clean_sheets': 3,
#    'goals_conceded': 20,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 1,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 8,
#    'bps': 267,
#    'influence': '373.2',
#    'creativity': '55.5',
#    'threat': '147.0',
#    'ict_index': '57.5',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2017/18',
#    'element_code': 126184,
#    'start_cost': 50,
#    'end_cost': 50,
#    'total_points': 102,
#    'minutes': 3352,
#    'goals_scored': 2,
#    'assists': 3,
#    'clean_sheets': 6,
#    'goals_conceded': 59,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 5,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 8,
#    'bps': 642,
#    'influence': '932.4',
#    'creativity': '115.1',
#    'threat': '287.0',
#    'ict_index': '133.5',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2018/19',
#    'element_code': 126184,
#    'start_cost': 50,
#    'end_cost': 51,
#    'total_points': 120,
#    'minutes': 3411,
#    'goals_scored': 4,
#    'assists': 1,
#    'clean_sheets': 10,
#    'goals_conceded': 70,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 3,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 8,
#    'bps': 716,
#    'influence': '1002.0',
#    'creativity': '125.9',
#    'threat': '440.0',
#    'ict_index': '156.8',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2019/20',
#    'element_code': 126184,
#    'start_cost': 50,
#    'end_cost': 48,
#    'total_points': 79,
#    'minutes': 2503,
#    'goals_scored': 2,
#    'assists': 2,
#    'clean_sheets': 4,
#    'goals_conceded': 46,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 2,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 6,
#    'bps': 499,
#    'influence': '691.2',
#    'creativity': '92.7',
#    'threat': '326.0',
#    'ict_index': '111.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2020/21',
#    'element_code': 126184,
#    'start_cost': 55,
#    'end_cost': 54,
#    'total_points': 29,
#    'minutes': 797,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 3,
#    'goals_conceded': 13,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 4,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 1,
#    'bps': 150,
#    'influence': '156.0',
#    'creativity': '46.9',
#    'threat': '44.0',
#    'ict_index': '24.7',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2021/22',
#    'element_code': 126184,
#    'start_cost': 50,
#    'end_cost': 47,
#    'total_points': 54,
#    'minutes': 919,
#    'goals_scored': 2,
#    'assists': 0,
#    'clean_sheets': 5,
#    'goals_conceded': 3,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 234,
#    'influence': '245.0',
#    'creativity': '58.9',
#    'threat': '75.0',
#    'ict_index': '37.9',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00'},
#   {'season_name': '2022/23',
#    'element_code': 126184,
#    'start_cost': 50,
#    'end_cost': 50,
#    'total_points': 92,
#    'minutes': 1871,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 9,
#    'goals_conceded': 15,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 2,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 9,
#    'bps': 419,
#    'influence': '405.2',
#    'creativity': '175.9',
#    'threat': '150.0',
#    'ict_index': '73.3',
#    'starts': 22,
#    'expected_goals': '1.55',
#    'expected_assists': '1.30',
#    'expected_goal_involvements': '2.85',
#    'expected_goals_conceded': '16.48'}]}

# %%
datasets.df_player_upcom_fixtures('Salah')
# Out:
#      event_name         team_h          team_a          kickoff_time  is_home  \
# 0   Gameweek 17      Liverpool         Man Utd  2023-12-17T16:30:00Z     True
# 1   Gameweek 18      Liverpool         Arsenal  2023-12-23T17:30:00Z     True
# 2   Gameweek 19        Burnley       Liverpool  2023-12-26T17:30:00Z    False
# 3   Gameweek 20      Liverpool       Newcastle  2024-01-01T20:00:00Z     True
# 4   Gameweek 21    Bournemouth       Liverpool  2024-01-21T16:30:00Z    False
# 5   Gameweek 22      Liverpool         Chelsea  2024-01-31T20:15:00Z     True
# 6   Gameweek 23        Arsenal       Liverpool  2024-02-03T15:00:00Z    False
# 7   Gameweek 24      Liverpool         Burnley  2024-02-10T15:00:00Z     True
# 8   Gameweek 25      Brentford       Liverpool  2024-02-17T15:00:00Z    False
# 9   Gameweek 26      Liverpool           Luton  2024-02-24T15:00:00Z     True
# 10  Gameweek 27  Nott'm Forest       Liverpool  2024-03-02T15:00:00Z    False
# 11  Gameweek 28      Liverpool        Man City  2024-03-09T15:00:00Z     True
# 12  Gameweek 29        Everton       Liverpool  2024-03-16T15:00:00Z    False
# 13  Gameweek 30      Liverpool        Brighton  2024-03-30T15:00:00Z     True
# 14  Gameweek 31      Liverpool   Sheffield Utd  2024-04-03T19:00:00Z     True
# 15  Gameweek 32        Man Utd       Liverpool  2024-04-06T14:00:00Z    False
# 16  Gameweek 33      Liverpool  Crystal Palace  2024-04-13T14:00:00Z     True
# 17  Gameweek 34         Fulham       Liverpool  2024-04-20T14:00:00Z    False
# 18  Gameweek 35       West Ham       Liverpool  2024-04-27T14:00:00Z    False
# 19  Gameweek 36      Liverpool           Spurs  2024-05-04T14:00:00Z     True
# 20  Gameweek 37    Aston Villa       Liverpool  2024-05-11T14:00:00Z    False
# 21  Gameweek 38      Liverpool          Wolves  2024-05-19T15:00:00Z     True
#
#     difficulty
# 0            3
# 1            4
# 2            2
# 3            4
# 4            2
# 5            3
# 6            4
# 7            2
# 8            3
# 9            2
# 10           2
# 11           5
# 12           2
# 13           3
# 14           2
# 15           4
# 16           2
# 17           2
# 18           3
# 19           3
# 20           3
# 21           2

# %%
plots.barplot_fplpoints_split(datasets.df_fplpoints_split())

# %%
plots.scatterplot_Goals_vs_xG(datasets.df_goals_vs_xg())

# %%
plots.barplot_fplpoints_per_position(datasets.df_fplpoints_per_position())

# %%
plots.scatterplot_Goals_Against_vs_xGA(datasets.df_goals_against_vs_xga(), save=True)
