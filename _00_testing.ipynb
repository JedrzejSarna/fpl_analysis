# %%
from _01_datasets import *
from _02_plots import *

# %%
datasets = DATASETS()
plots = PLOTS()

# %%
datasets.build_players_dataset()
datasets.build_teams_dataset()
datasets.build_gameweeks_dataset()
datasets.build_positions_dataset()

# %%
datasets.transform_players_dataset()

# %%
datasets.df_GA_vs_xGA_performance().head(10)
# Out:
#     player_name  expected_goal_involvements  goal_involvements  overperform
# 5       Watkins                        9.37                 17         7.63
# 579      Gordon                        5.89                 11         5.11
# 372       Diaby                        5.24                 10         4.76
# 659        Neto                        4.72                  9         4.28
# 457    Sterling                        4.93                  9         4.07
# 649       Kudus                        2.12                  6         3.88
# 62      Haaland                       15.29                 19         3.71
# 322      Coufal                        1.31                  5         3.69
# 61    J.Alvarez                        7.39                 11         3.61
# 556        Doku                        3.43                  7         3.57

# %%
plots.barplot_top5_GA_vs_XGA(datasets.df_GA_vs_xGA_performance())
#ADD LEGEND

# %%
datasets.df_GA_vs_xGA_performance().tail(10)
# Out:
#     player_name  expected_goal_involvements  goal_involvements  overperform
# 109        Cash                        4.84                  3        -1.84
# 330   Aït-Nouri                        1.95                  0        -1.95
# 488       Onana                        1.95                  0        -1.95
# 30    N.Jackson                        9.00                  7        -2.00
# 374     Zaniolo                        2.03                  0        -2.03
# 140        Dunk                        3.12                  1        -2.12
# 569    Rashford                        6.31                  4        -2.31
# 494       Iwobi                        3.34                  1        -2.34
# 452        Enzo                        5.38                  3        -2.38
# 65      Højlund                        2.97                  0        -2.97

# %%
datasets.players_dataset
# Out:
#     player_name  price_change_start  dreamteam_count exp_pts_next  \
# 0       Balogun                  -1                0          0.0
# 1       G.Jesus                  -1                0          2.0
# 2       Nketiah                   1                1          2.2
# 3         Davis                  -1                0          0.0
# 4         Duran                   0                0         -0.8
# ..          ...                 ...              ...          ...
# 748       Anang                   0                0          0.0
# 749     Bentley                  -1                1          3.2
# 750        King                   0                0          0.5
# 751     José Sá                   0                1          1.4
# 752      Šarkić                   0                0          0.0
#
#     exp_pts_this  event_points form  player_id  price points_per_game  \
# 0            0.0             0  0.0          1     44             0.0
# ...

# %%
datasets.teams_dataset
# Out:
#               name short_name  strength  strength_overall_home  \
# id
# 1          Arsenal        ARS         4                   1230
# 2      Aston Villa        AVL         3                   1115
# 3      Bournemouth        BOU         3                   1060
# 4        Brentford        BRE         3                   1125
# 5         Brighton        BHA         3                   1165
# 6          Burnley        BUR         2                   1060
# 7          Chelsea        CHE         3                   1115
# 8   Crystal Palace        CRY         3                   1100
# 9          Everton        EVE         3                   1075
# 10          Fulham        FUL         3                   1095
# 11       Liverpool        LIV         4                   1220
# 12           Luton        LUT         2                   1045
# 13        Man City        MCI         5                   1350
# 14         Man Utd        MUN         4                   1145
# ...

# %%
plots.pointplot_top5_player_points(datasets.df_top5_player_pts(), save=True)

# %%
plots.pointplot_top5_defender_points(datasets.df_top5_defender_pts())

# %%
plots.pointplot_top5_midfielder_points(datasets.df_top5_midfielder_pts())

# %%
plots.pointplot_top5_forward_points(datasets.df_top5_forward_pts())

# %%
datasets.get_player_id("Cash")
# Out:
# 36

# %%
datasets.df_player_season('Saka')
# Out:
#      opponent_team  total_points  was_home          kickoff_time  \
# 0    Nott'm Forest            10      True  2023-08-12T12:00:00Z
# 1   Crystal Palace             3     False  2023-08-21T19:00:00Z
# 2           Fulham             8      True  2023-08-26T14:00:00Z
# 3          Man Utd             4      True  2023-09-03T15:30:00Z
# 4          Everton             6     False  2023-09-17T15:30:00Z
# 5            Spurs            13      True  2023-09-24T13:00:00Z
# 6      Bournemouth             9     False  2023-09-30T14:00:00Z
# 7         Man City             0      True  2023-10-08T15:30:00Z
# 8          Chelsea             5     False  2023-10-21T16:30:00Z
# 9    Sheffield Utd             6      True  2023-10-28T14:00:00Z
# 10       Newcastle             2     False  2023-11-04T17:30:00Z
# 11         Burnley             5      True  2023-11-11T15:00:00Z
# 12       Brentford             8     False  2023-11-25T17:30:00Z
# ...

# %%
datasets.df_player_past_seasons('Haaland')
# Out:
#   season_name  start_cost  end_cost  total_points  minutes  goals_scored  \
# 0     2022/23         115       124           272     2767            36
#
#    assists  clean_sheets  goals_conceded  own_goals  penalties_saved  \
# 0        9            13              26          0                0
#
#    penalties_missed  yellow_cards  red_cards  saves  bonus   bps influence  \
# 0                 0             5          0      0     40  1040    1390.0
#
#   creativity  threat ict_index  starts expected_goals expected_assists  \
# 0      371.0  1825.0     358.1      33          28.54             3.11
#
#   expected_goal_involvements expected_goals_conceded
# 0                      31.65                   25.24

# %%
datasets.get_player_json('Bukayo Saka')
# Out:
# {'fixtures': [{'id': 126,
#    'code': 2367663,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 11,
#    'team_a_score': None,
#    'event': 13,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-11-25T12:30:00Z',
#    'event_name': 'Gameweek 13',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 137,
#    'code': 2367674,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 18,
#    'team_a_score': None,
#    'event': 14,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-03T16:30:00Z',
#    'event_name': 'Gameweek 14',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 141,
#    'code': 2367678,
#    'team_h': 2,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 15,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-06T20:15:00Z',
# ...

# %%
datasets.df_player_upcom_fixtures('Salah')
# Out:
#      event_name          team_h          team_a          kickoff_time  \
# 0   Gameweek 13        Man City       Liverpool  2023-11-25T12:30:00Z
# 1   Gameweek 14       Liverpool          Fulham  2023-12-03T14:00:00Z
# 2   Gameweek 15   Sheffield Utd       Liverpool  2023-12-06T19:30:00Z
# 3   Gameweek 16  Crystal Palace       Liverpool  2023-12-09T12:30:00Z
# 4   Gameweek 17       Liverpool         Man Utd  2023-12-17T16:30:00Z
# 5   Gameweek 18       Liverpool         Arsenal  2023-12-23T17:30:00Z
# 6   Gameweek 19         Burnley       Liverpool  2023-12-26T17:30:00Z
# 7   Gameweek 20       Liverpool       Newcastle  2024-01-01T20:00:00Z
# 8   Gameweek 21     Bournemouth       Liverpool  2024-01-21T16:30:00Z
# 9   Gameweek 22       Liverpool         Chelsea  2024-01-31T20:00:00Z
# 10  Gameweek 23         Arsenal       Liverpool  2024-02-03T15:00:00Z
# 11  Gameweek 24       Liverpool         Burnley  2024-02-10T15:00:00Z
# ...

# %%
datasets.df_fplpoints_split()
# Out:
#                                          Action  Percentage (%)
# 0                                  > 60 minutes           54.52
# 1                                         Goals           17.39
# 2                                  Clean Sheets           13.54
# 3                                       Assists           10.04
# 4                                  Bonus points            7.94
# 5                                  < 60 minutes            2.59
# 6                                         Saves            0.76
# 7  Penalty saves \n Penalty misses \n Own goals           -0.35
# 8                                     Red cards           -0.84
# 9                                  Yellow cards           -5.67

# %%
plots.barplot_fplpoints_split(datasets.df_fplpoints_split())

# %%
datasets.df_fplpoints_per_club()
# Out:
# team_name
# Arsenal           639
# Aston Villa       563
# Bournemouth       382
# Brentford         516
# Brighton          479
# Burnley           309
# Chelsea           518
# Crystal Palace    496
# Everton           411
# Fulham            425
# Liverpool         623
# Luton             351
# Man City          651
# Man Utd           505
# Newcastle         615
# Nott'm Forest     461
# Sheffield Utd     287
# Spurs             575
# West Ham          474
# Wolves            404
# Name: total_points, dtype: int64

# %%
datasets.df_goals_vs_xg()
# Out:
#                 expected_goals  goals_scored
# team_name
# Arsenal                  21.86            25
# Aston Villa              24.58            26
# Bournemouth              14.42            11
# Brentford                24.13            18
# Brighton                 21.46            23
# Burnley                  10.04             9
# Chelsea                  24.82            20
# Crystal Palace           14.58            12
# Everton                  17.18            14
# Fulham                   13.20             9
# Liverpool                27.10            25
# Luton                    13.27             9
# Man City                 25.08            32
# Man Utd                  17.23            13
# Newcastle                23.85            27
# Nott'm Forest            13.16            14
# Sheffield Utd             9.91             7
# Spurs                    19.53            21
# West Ham                 18.16            21
# Wolves                   16.52            15

# %%
plots.scatterplot_Goals_vs_xG(datasets.df_goals_vs_xg(), save=True)

# %%
plots.barplot_fplpoints_per_club(datasets.df_fplpoints_per_club())

# %%
datasets.df_fplpoints_per_position()
# Out:
#                 sum       mean  count
# position_name
# Goalkeeper      776  28.740741     27
# Defender       2956  18.360248    161
# Midfielder     4531  20.409910    222
# Forward        1422  24.101695     59

# %%
plots.barplot_fplpoints_per_position(datasets.df_fplpoints_per_position())

# %%
datasets.df_goals_against_vs_xga()
# Out:
#                 expected_goals_conceded  goals_conceded
# team_name
# Arsenal                            9.55              10
# Aston Villa                       15.71              17
# Bournemouth                       24.59              27
# Brentford                         16.50              17
# Brighton                          18.03              21
# Burnley                           22.37              30
# Chelsea                           15.34              16
# Crystal Palace                    17.70              16
# Everton                           16.35              17
# Fulham                            22.52              20
# Liverpool                         14.33              10
# Luton                             25.27              22
# Man City                          11.18              12
# Man Utd                           19.10              16
# Newcastle                         13.95              13
# Nott'm Forest                     18.24              18
# ...

# %%
plots.scatterplot_Goals_Against_vs_xGA(datasets.df_goals_against_vs_xga(), save=True)
